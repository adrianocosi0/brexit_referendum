# %%
#!/usr/bin/python
# -*- coding: utf-8 -*-
import pandas as pd
import numpy as np
from pandas import Series, DataFrame
from lxml.html import parse
from urllib2 import urlopen
from pandas.io.parsers import TextParser

parsed = parse(urlopen('https://ig.ft.com/sites/elections/2016/uk/eu-referendum/'))
doc = parsed.getroot()
tables = doc.findall('.//table')

#function to extract row elements from table row

def unpack(rows, kind='td'):
	elts = rows.findall('.//{}'.format(kind))
	return [a.text_content().strip() for a in elts]

#function to parse votes' website data to DataFrame

def extract_votes_data(tab):
	rows = tab.findall('.//tr')
	header = unpack(rows[0], 'th')
    #each unpacked row is converted into an array to allow for explicit indexing. the row is then reconverted into a list
	values = [list(np.array(unpack(row))[[0,2,3]]) for row in rows[1:]]
	#TextParser is an iterable object, get_chunk method returns all rows by default
	return TextParser(values, names=['Borough']+header[3:], thousands=',').get_chunk()

referendum_votes = extract_votes_data(tables[0]).set_index('Borough')

def comp_percent(frame, total_column):
    '''method to substitute total numbers with percentages'''
    for col in frame.columns[:-1]:
        frame[col] = frame[col]/frame[total_column]

#add Total Column to apply method

referendum_votes['Total'] = referendum_votes.sum(axis=1)

comp_percent(referendum_votes, 'Total')

'''the dataframe for referendum votes contains boroughs for all UK but later, when the dataframes are merged,
these will be discarded'''

'''Proceed to parse excel data into dataframe. Data comes from gov.uk,it 
is by London neighbourhood and datasets cover: fear of crime, ethnicity, 
average earnings, mayor elections total votes by parties (democratic, liberal, green).
Data comes in xls format'''

mayor_votes = pd.read_excel("https://files.datapress.com/london/dataset/london-elections-results-2016-wards-boroughs-constituency/2016-05-27T10:46:12/gla-elections-votes-all-2016.xlsx",
                            sheetname='Boroughs', parse_cols=[0,4,5,62,63,64,65,66,67,68,69,70,71,72,73,74,75], header=2, skip_rows=34)

print mayor_votes.head()

#the boroughs containing & are renamed to allow for merging. the entries would drop otherwise
mayor_votes = mayor_votes.rename(index={'Barking & Dagenham':'Barking and Dagenham', 'Hammersmith & Fulham': 'Hammersmith and Fulham',
								'Kensington & Chelsea':'Kensington and Chelsea'})

#new dataframe as we want to calculate % Turnout and avoid to divide the other columns by the Ward Level Electorate
Turnout = mayor_votes.ix[:,['Turnout', 'Ward Level Electorate']]

Turnout.index = mayor_votes.index

comp_percent(Turnout, 'Ward Level Electorate')

print Turnout.head()

for a in ['Turnout', 'Ward Level Electorate']:
	del mayor_votes[a]

comp_percent(mayor_votes, 'Total Good')

'''Parse fear of crime data'''

fear_crime = pd.read_excel("https://files.datapress.com/london/dataset/metropolitan-police-service-recorded-crime-figures-and-associated-data/2016-08-02T16:30:12/MASTER_mps-figures_new.xls",
                           sheetname='Fear of Crime-Borough', skip_rows=[0,1], header=2)

print fear_crime.head()

#only the most recent period is relevant for the analysis and would like to index the dataframe by borough

fear_crime = fear_crime.ix[31,1:]

print fear_crime.head()

'''Parse ethnicity data'''

#is the skip_rows needed or not? try without
ethnicity_data = pd.read_excel("https://files.datapress.com/london/dataset/ethnic-groups-gender-borough/2015-12-29T14:48:50/ethnic-groups-by-borough.xls",
                               sheetname='2014', index_col='Area', thousands=',')

print ethnicity_data.head()

del ethnicity_data['Code']

ethnicity_data = ethnicity_data.dropna()

# the '-' is not recognized by pandas
ethnicity_data.loc['City of London'] = np.NaN

comp_percent(ethnicity_data, 'Total')

'''Parse earnings data'''

earnings = pd.read_excel("https://files.datapress.com/london/dataset/earnings-place-residence-borough/2015-11-25T15:30:53/earnings-residence-borough.xls",
                         sheetname='Total, weekly', skip_rows=[0], header = 1, parse_cols = [1,28,29,30])

print earnings.head()

earnings.loc['City of London'] = np.NaN

earnings.dropna()

'''Proceed to merge all data in a dataframe'''

frames = [referendum_votes, mayor_votes, ethnicity_data, earnings, Turnout]

#merge on dataframes
a = reduce(lambda x,y: x.merge(y, how='inner', suffixes=('x','y'), left_index=True, right_index=True), frames)
#join fear_crime which is a Series object
b = a.join(fear_crime, how='inner')
print all_data.head()
#NA values are approximated to no votes in the Borough for the party
all_data = all_data.fillna(0)
all_data = all_data.rename(index=str, columns={31:'Fear Crime', u'Pay (£)':'2015 Pay'})
#check which boroughs dropped out. City of london drops out as a lot of datasets lack information on the borough, Kingston and Richmond are not in the FT dataset
print mayor_votes.index.difference(all_data.index)
#this is to group minor political parties and facilitate the analysis
all_data['Other Party'] = all_data[['Liberal Democrats', "All People's Party", 'Respect (George Galloway)', 'Take Back the City']].sum(axis=1)
all_data.to_csv('all_data', encoding='utf-8', index_label='Borough')
# Out:
#                     Turnout  Ward Level Electorate  Total spoils  \
# Barking & Dagenham    46135                 127128           473
# Barnet               114626                 233810          1135
# Bexley                75537                 171544           766
# Brent                 92197                 212227          1490
# Bromley              116007                 232785           997
#
#                     Labour Party  Conservative Party  Green Party  \
# Barking & Dagenham         23696                7207         2492
# Barnet                     46381               47920         7504
# Bexley                     19726               32353         3651
# Brent                      46912               23530         6019
# Bromley                    26065               55107         9034
#
#                     Liberal Democrats  UK Independence Party (UKIP)  \
# Barking & Dagenham               1571                          9280
# Barnet                           5583                          6083
# Bexley                           3264                         15058
# Brent                            6962                          3827
# Bromley                          8881                         15427
#
#                     All People's Party  Respect (George Galloway)  \
# Barking & Dagenham                 229                        943
# Barnet                             NaN                        NaN
# Bexley                             735                        NaN
# Brent                              NaN                       3346
# Bromley                             58                        NaN
#
#                     Take Back the City  National Front  \
# Barking & Dagenham                  22             NaN
# Barnet                             NaN             NaN
# Bexley                             NaN             NaN
# Brent                              NaN             NaN
# Bromley                            NaN             NaN
#
#                     The Socialist Party (SP-GB)  Independent  \
# Barking & Dagenham                          NaN          NaN
# Barnet                                      NaN          NaN
# Bexley                                      NaN          NaN
# Brent                                       NaN          NaN
# Bromley                                     NaN          NaN
#
#                     Communist League  Total Good
# Barking & Dagenham               NaN       45638
# Barnet                           NaN      113471
# Bexley                           NaN       74787
# Brent                            NaN       90596
# Bromley                          NaN      115022
#                        Turnout  Ward Level Electorate
# Barking and Dagenham  0.362902                 127128
# Barnet                0.490253                 233810
# Bexley                0.440336                 171544
# Brent                 0.434426                 212227
# Bromley               0.498344                 232785
#   Month-Year Barking and Dagenham    Barnet    Bexley     Brent   Bromley  \
# 0 2008-06-01             0.374038  0.338416  0.491964   0.43476  0.413844
# 1 2008-09-01             0.464132  0.362306  0.426416  0.447633  0.393903
# 2 2008-09-01             0.491409   0.39503  0.381165  0.466894  0.300957
# 3 2009-03-01             0.483112  0.381918  0.297508  0.472423  0.335428
# 4 2009-06-01             0.390544  0.353807   0.27867  0.405839  0.311586
#
#      Camden   Croydon    Ealing   Enfield    ...       Newham Redbridge  \
# 0  0.598477  0.431842  0.507752  0.476963    ...     0.714465  0.409705
# 1  0.733636  0.449706  0.573461  0.487327    ...     0.726763  0.463524
# 2  0.756835  0.476073  0.569613  0.438438    ...     0.737958  0.408958
# 3  0.811846  0.428503  0.467042  0.418782    ...     0.704997  0.342885
# 4   0.59372  0.456931  0.471381  0.449171    ...     0.644706  0.445011
#
#   Richmond upon Thames Southwark    Sutton Tower Hamlets Waltham Forest  \
# 0             0.209203  0.243986   0.49671      0.481933       0.299313
# 1             0.174764   0.33429  0.478358      0.483861       0.317007
# 2              0.10802  0.335516  0.423974      0.528766       0.338656
# 3            0.0416639  0.389633  0.433128      0.534101       0.310045
# 4            0.0362852  0.422575  0.452727      0.486677       0.271753
#
#   Wandsworth Westminster       MPS
# 0   0.218583    0.347506  0.404751
# 1   0.132808    0.381658  0.404858
# 2   0.379969    0.470064  0.412135
# 3   0.438275     0.43617  0.382951
# 4   0.374282     0.38452  0.361912
#
# [5 rows x 34 columns]
# Barking and Dagenham     0.38292
# Barnet                  0.347401
# Bexley                  0.329563
# Brent                   0.397136
# Bromley                 0.281516
# Name: 31, dtype: object
#                            Code   White  Mixed  Asian  Black Chinese/ Other  \
# Area
# NaN                         NaN     NaN    NaN    NaN    NaN            NaN
# City of London        E09000001       -      -      -      -              -
# Barking and Dagenham  E09000002   98400   7500  31500  43600          16000
# Barnet                E09000003  243600  21700  47700  15700          40500
# Bexley                E09000004  190500   4100   7700  29900           4000
#
#                        Total
# Area
# NaN                      NaN
# City of London             -
# Barking and Dagenham  197000
# Barnet                369100
# Bexley                236200
#                      Pay (£) conf %
# NaN                      NaN    NaN
# City of London             #      #
# Barking and Dagenham   436.4    5.6
# Barnet                 497.7    4.9
# Bexley                 493.4    4.8
#                       Remain votes  Leave votes  Totalx  Total spoils  \
# Barking and Dagenham      0.375609     0.624391   73880      0.010364
# Barnet                    0.622295     0.377705  161033      0.010003
# Bexley                    0.370483     0.629517  128489      0.010242
# Brent                     0.597369     0.402631  121404      0.016447
# Bromley                   0.506479     0.493521  182432      0.008668
#
#                       Labour Party  Conservative Party  Green Party  \
# Barking and Dagenham      0.519216            0.157917     0.054604
# Barnet                    0.408748            0.422311     0.066131
# Bexley                    0.263762            0.432602     0.048819
# Brent                     0.517815            0.259724     0.066438
# Bromley                   0.226609            0.479100     0.078541
#
#                       Liberal Democrats  UK Independence Party (UKIP)  \
# Barking and Dagenham           0.034423                      0.203339
# Barnet                         0.049202                      0.053608
# Bexley                         0.043644                      0.201345
# Brent                          0.076847                      0.042242
# Bromley                        0.077211                      0.134122
#
#                       All People's Party     ...          Mixed     Asian  \
# Barking and Dagenham            0.005018     ...       0.038071  0.159898
# Barnet                          0.000000     ...       0.058792  0.129233
# Bexley                          0.009828     ...       0.017358  0.032599
# Brent                           0.000000     ...       0.038629  0.299377
# Bromley                         0.000504     ...       0.035182  0.059905
#
#                          Black  Chinese/ Other  Totaly  2015 Pay  conf %  \
# Barking and Dagenham  0.221320        0.081218  197000     436.4     5.6
# Barnet                0.042536        0.109726  369100     497.7     4.9
# Bexley                0.126588        0.016935  236200     493.4     4.8
# Brent                 0.167913        0.126480  321000     454.6     4.3
# Bromley               0.042472        0.016482  315500     583.8     3.9
#
#                       Fear Crime  Turnout  Other Party
# Barking and Dagenham    0.382920    46135     0.060585
# Barnet                  0.347401   114626     0.049202
# Bexley                  0.329563    75537     0.053472
# Brent                   0.397136    92197     0.113780
# Bromley                 0.281516   116007     0.077716
#
# [5 rows x 28 columns]
# Index([u'City of London', u'Kingston upon Thames', u'London',
#        u'Richmond upon Thames'],
#       dtype='object')
